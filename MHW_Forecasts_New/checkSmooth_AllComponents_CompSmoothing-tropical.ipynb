# %%
import os
import sys
import subprocess
import datetime as dt
import itertools
import numpy as np
import xarray as xr
from dask.distributed import Client, LocalCluster, wait
import dask.array as da
import matplotlib.pyplot as plt
import cmocean
from MHW_daily_calcs import *

# %% [markdown]
# #### Calculate equivalent SST thresholds that applied to raw SST to see if they are smooth in time

# %%
climyrs=[1993,2023]
qtile=0.90
smoothmethod='tri'
window=10
delt=5
#tropical location:
iy=115
ix=200

# %%
cluster = LocalCluster(n_workers=6,threads_per_worker=1,dashboard_address='localhost:54924')
client = Client(cluster)
# Out:
# /home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/distributed/node.py:187: UserWarning: Port 54924 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 44749 instead
#   warnings.warn(

# %%
flistclim = [fnameCanESMClim(workdir,climyrs[0],climyrs[-1],mm) for mm in range(1,13)]
fclim=xr.open_mfdataset(flistclim,combine='nested',concat_dim='month',parallel=True,decode_times=False)

# %%
method='tri'
halfwin=10

# %%
flclimS=[fnameCanESMClimSmooth(workdir,climyrs[0],climyrs[-1],mm, method, halfwin) for mm in range(1,13)]
fclimS=xr.open_mfdataset(flclimS,combine='nested',concat_dim='month',parallel=True,decode_times=False)

# %% [raw]
# # check that files have data
# for mm in range(0,12):
#     for ilead in range(0,215):
#         sumnum=
#         print(f"{mm:02}, {ilead:03}, {np.sum(~np.isnan(fthr.qt.isel(month=mm,leadtime=ilead).values))}")

# %%
#clim only
fig,ax=plt.subplots(1,1,figsize=(12,7))
for mm in range(1,13):
    t=(dt.datetime(2024,mm,1)-dt.datetime(2023,12,31)).total_seconds()/(24*3600)+fclim.leadtime.values/24
    t=t%365
    m=ax.scatter(t,fclim.tso.isel(month=mm-1,lat=iy,lon=ix).values,c=fclim.leadtime.values/24,s=3,cmap=plt.get_cmap('jet'),alpha=.3)
fig.colorbar(m,label='lead time (days)')
ax.set_title('SST Climatology')
ax.set_xlabel('Day of Year')
ax.set_ylabel('SST (K)')
ax.set_xlim(0,366)
# Out:
# (0.0, 366.0)

# %%
#clim only
fig,ax=plt.subplots(1,1,figsize=(12,7))
for mm in range(1,13):
    t=(dt.datetime(2024,mm,1)-dt.datetime(2023,12,31)).total_seconds()/(24*3600)+fclimS.leadtime.values/24
    t=t%365
    m=ax.scatter(t,fclimS.tso.isel(month=mm-1,lat=iy,lon=ix).values,c=fclimS.leadtime.values/24,s=3,cmap=plt.get_cmap('jet'),alpha=.3)
fig.colorbar(m,label='lead time (days)')
ax.set_title('SST Smoothed Climatology')
ax.set_xlabel('Day of Year')
ax.set_ylabel('SST (K)')
ax.set_xlim(0,366)
# Out:
# (0.0, 366.0)

# %% [markdown]
# ### now detrended version

# %% [markdown]
# first check trends

# %%
flistb=[[fnameCanESMDetrFitByLead(workdir, climyrs[0],climyrs[-1], ilead, yind) for yind in [0,60,120]] for ilead in range(0,215)]
fb=xr.open_mfdataset(flistb,combine='nested',concat_dim=['leadtime','lat'],parallel=True,decode_times=False)
desstr=f'_ClimS{smoothmethod}{window}'
flistbS0=[[fnameCanESMDetrFitByLead(workdir, climyrs[0],climyrs[-1], ilead, yind,desstr) for yind in [0,60,120]] for ilead in range(0,215)]
fbS0=xr.open_mfdataset(flistbS0,combine='nested',concat_dim=['leadtime','lat'],parallel=True,decode_times=False)
flistbS=[[fnameCanESMDetrFitByLeadS(workdir, climyrs[0],climyrs[-1], ilead, yind,'tri',10,desstr) for yind in [0,60,120]] for ilead in range(0,215)]
fbS=xr.open_mfdataset(flistbS,combine='nested',concat_dim=['leadtime','lat'],parallel=True,decode_times=False)
# Out:
# 2024-11-27 22:26:20,904 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-a5dff794-1652-486d-a7ce-bd7e235d4375
# State:     executing
# Function:  execute_task
# args:      ((<function apply at 0x147fb4c456c0>, <function open_dataset at 0x147f96210220>, ['/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L107_j120_ocean_1d_surface_tso.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [])], ['decode_times', False]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/dask/utils.py", line 78, in apply\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py", line 611, in open_dataset\n    backend_ds = backend.open_dataset(\n                 ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 649, in open_dataset\n    store = NetCDF4DataStore.open(\n            ^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 410, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 357, in __init__\n    self.format = self.ds.data_model\n                  ^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 419, in ds\n    return self._acquire()\n           ^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 413, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/contextlib.py", line 137, in __enter__\n    return next(self.gen)\n           ^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "src/netCDF4/_netCDF4.pyx", line 2470, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2107, in netCDF4._netCDF4._ensure_nc_success\n'
#
# 2024-11-27 22:26:20,906 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-332f14a5-9394-4025-816c-e008c288ac1c
# State:     executing
# Function:  execute_task
# args:      ((<function apply at 0x14e3c10716c0>, <function open_dataset at 0x14e3a263c0e0>, ['/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L031_j000_ocean_1d_surface_tso.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [])], ['decode_times', False]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/dask/utils.py", line 78, in apply\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py", line 611, in open_dataset\n    backend_ds = backend.open_dataset(\n                 ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 649, in open_dataset\n    store = NetCDF4DataStore.open(\n            ^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 410, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 357, in __init__\n    self.format = self.ds.data_model\n                  ^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 419, in ds\n    return self._acquire()\n           ^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 413, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/contextlib.py", line 137, in __enter__\n    return next(self.gen)\n           ^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "src/netCDF4/_netCDF4.pyx", line 2470, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2107, in netCDF4._netCDF4._ensure_nc_success\n'
#
# 2024-11-27 22:26:20,908 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-936f1596-26ac-4d7e-b825-a8640c91c3b8
# State:     executing
# Function:  execute_task
# args:      ((<function apply at 0x14a4109dd6c0>, <function open_dataset at 0x14a3f1f98040>, ['/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L131_j120_ocean_1d_surface_tso.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [])], ['decode_times', False]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/dask/utils.py", line 78, in apply\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py", line 611, in open_dataset\n    backend_ds = backend.open_dataset(\n                 ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 649, in open_dataset\n    store = NetCDF4DataStore.open(\n            ^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 410, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 357, in __init__\n    self.format = self.ds.data_model\n                  ^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 419, in ds\n    return self._acquire()\n           ^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 413, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/contextlib.py", line 137, in __enter__\n    return next(self.gen)\n           ^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "src/netCDF4/_netCDF4.pyx", line 2470, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2107, in netCDF4._netCDF4._ensure_nc_success\n'
#
# 2024-11-27 22:26:20,909 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-6d8db1ec-32db-4434-a5f4-ba433eed19a9
# State:     executing
# Function:  execute_task
# args:      ((<function apply at 0x147fb4c456c0>, <function open_dataset at 0x147f96210220>, ['/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L141_j000_ocean_1d_surface_tso.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [])], ['decode_times', False]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/dask/utils.py", line 78, in apply\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py", line 611, in open_dataset\n    backend_ds = backend.open_dataset(\n                 ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 649, in open_dataset\n    store = NetCDF4DataStore.open(\n            ^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 410, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 357, in __init__\n    self.format = self.ds.data_model\n                  ^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 419, in ds\n    return self._acquire()\n           ^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 413, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/contextlib.py", line 137, in __enter__\n    return next(self.gen)\n           ^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "src/netCDF4/_netCDF4.pyx", line 2470, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2107, in netCDF4._netCDF4._ensure_nc_success\n'
#
# 2024-11-27 22:26:20,909 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-d1bbad03-ca44-42e5-bda8-1505e454e41e
# State:     executing
# Function:  execute_task
# args:      ((<function apply at 0x14e3c10716c0>, <function open_dataset at 0x14e3a263c0e0>, ['/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L160_j120_ocean_1d_surface_tso.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [])], ['decode_times', False]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/dask/utils.py", line 78, in apply\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py", line 611, in open_dataset\n    backend_ds = backend.open_dataset(\n                 ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 649, in open_dataset\n    store = NetCDF4DataStore.open(\n            ^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 410, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 357, in __init__\n    self.format = self.ds.data_model\n                  ^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 419, in ds\n    return self._acquire()\n           ^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 413, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/contextlib.py", line 137, in __enter__\n    return next(self.gen)\n           ^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "src/netCDF4/_netCDF4.pyx", line 2470, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2107, in netCDF4._netCDF4._ensure_nc_success\n'
#
# 2024-11-27 22:26:20,910 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-3c2e15cf-2108-453a-867b-c10dd39f8046
# State:     executing
# Function:  execute_task
# args:      ((<function apply at 0x14d7562fd6c0>, <function open_dataset at 0x14d737824220>, ['/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L069_j060_ocean_1d_surface_tso.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [])], ['decode_times', False]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/dask/utils.py", line 78, in apply\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py", line 611, in open_dataset\n    backend_ds = backend.open_dataset(\n                 ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 649, in open_dataset\n    store = NetCDF4DataStore.open(\n            ^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 410, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 357, in __init__\n    self.format = self.ds.data_model\n                  ^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 419, in ds\n    return self._acquire()\n           ^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 413, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/contextlib.py", line 137, in __enter__\n    return next(self.gen)\n           ^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "src/netCDF4/_netCDF4.pyx", line 2470, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2107, in netCDF4._netCDF4._ensure_nc_success\n'
#
# 2024-11-27 22:26:20,911 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-7de620f1-105c-414c-90bd-26ad3680c68c
# State:     executing
# Function:  execute_task
# args:      ((<function apply at 0x14849a6cd6c0>, <function open_dataset at 0x14847bc28360>, ['/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L169_j060_ocean_1d_surface_tso.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [])], ['decode_times', False]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/dask/utils.py", line 78, in apply\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py", line 611, in open_dataset\n    backend_ds = backend.open_dataset(\n                 ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 649, in open_dataset\n    store = NetCDF4DataStore.open(\n            ^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 410, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 357, in __init__\n    self.format = self.ds.data_model\n                  ^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 419, in ds\n    return self._acquire()\n           ^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 413, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/contextlib.py", line 137, in __enter__\n    return next(self.gen)\n           ^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "src/netCDF4/_netCDF4.pyx", line 2470, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2107, in netCDF4._netCDF4._ensure_nc_success\n'
#
# 2024-11-27 22:26:20,912 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-53995eaf-1830-41e4-b72d-3f7e1f1b5faf
# State:     executing
# Function:  execute_task
# args:      ((<function apply at 0x147fb4c456c0>, <function open_dataset at 0x147f96210220>, ['/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L028_j120_ocean_1d_surface_tso.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [])], ['decode_times', False]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/dask/utils.py", line 78, in apply\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py", line 611, in open_dataset\n    backend_ds = backend.open_dataset(\n                 ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 649, in open_dataset\n    store = NetCDF4DataStore.open(\n            ^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 410, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 357, in __init__\n    self.format = self.ds.data_model\n                  ^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 419, in ds\n    return self._acquire()\n           ^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 413, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/contextlib.py", line 137, in __enter__\n    return next(self.gen)\n           ^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "src/netCDF4/_netCDF4.pyx", line 2470, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2107, in netCDF4._netCDF4._ensure_nc_success\n'
#
# 2024-11-27 22:26:20,913 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-a434088c-758c-4de4-9d81-609e54b507d8
# State:     executing
# Function:  execute_task
# args:      ((<function apply at 0x14e3c10716c0>, <function open_dataset at 0x14e3a263c0e0>, ['/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L111_j060_ocean_1d_surface_tso.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [])], ['decode_times', False]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/dask/utils.py", line 78, in apply\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py", line 611, in open_dataset\n    backend_ds = backend.open_dataset(\n                 ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 649, in open_dataset\n    store = NetCDF4DataStore.open(\n            ^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 410, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 357, in __init__\n    self.format = self.ds.data_model\n                  ^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 419, in ds\n    return self._acquire()\n           ^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 413, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/contextlib.py", line 137, in __enter__\n    return next(self.gen)\n           ^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "src/netCDF4/_netCDF4.pyx", line 2470, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2107, in netCDF4._netCDF4._ensure_nc_success\n'
#
# 2024-11-27 22:26:20,914 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-b1a5736d-313f-4c21-9d32-0b9a90f411fd
# State:     executing
# Function:  execute_task
# args:      ((<function apply at 0x14a4109dd6c0>, <function open_dataset at 0x14a3f1f98040>, ['/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L092_j000_ocean_1d_surface_tso.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [])], ['decode_times', False]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/dask/utils.py", line 78, in apply\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py", line 611, in open_dataset\n    backend_ds = backend.open_dataset(\n                 ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 649, in open_dataset\n    store = NetCDF4DataStore.open(\n            ^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 410, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 357, in __init__\n    self.format = self.ds.data_model\n                  ^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 419, in ds\n    return self._acquire()\n           ^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 413, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/contextlib.py", line 137, in __enter__\n    return next(self.gen)\n           ^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "src/netCDF4/_netCDF4.pyx", line 2470, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2107, in netCDF4._netCDF4._ensure_nc_success\n'
#
# 2024-11-27 22:26:20,914 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-4d4ff3d6-313e-492f-9308-142631b09e9c
# State:     executing
# Function:  execute_task
# args:      ((<function apply at 0x14849a6cd6c0>, <function open_dataset at 0x14847bc28360>, ['/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L205_j000_ocean_1d_surface_tso.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [])], ['decode_times', False]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/dask/utils.py", line 78, in apply\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py", line 611, in open_dataset\n    backend_ds = backend.open_dataset(\n                 ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 649, in open_dataset\n    store = NetCDF4DataStore.open(\n            ^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 410, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 357, in __init__\n    self.format = self.ds.data_model\n                  ^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 419, in ds\n    return self._acquire()\n           ^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 413, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/contextlib.py", line 137, in __enter__\n    return next(self.gen)\n           ^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "src/netCDF4/_netCDF4.pyx", line 2470, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2107, in netCDF4._netCDF4._ensure_nc_success\n'
#
# 2024-11-27 22:26:20,927 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-80bb2db0-afd0-4896-902f-f7621ca4a93c
# State:     executing
# Function:  execute_task
# args:      ((<function apply at 0x14a4109dd6c0>, <function open_dataset at 0x14a3f1f98040>, ['/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L170_j000_ocean_1d_surface_tso.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [])], ['decode_times', False]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/dask/utils.py", line 78, in apply\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py", line 611, in open_dataset\n    backend_ds = backend.open_dataset(\n                 ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 649, in open_dataset\n    store = NetCDF4DataStore.open(\n            ^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 410, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 357, in __init__\n    self.format = self.ds.data_model\n                  ^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 419, in ds\n    return self._acquire()\n           ^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 413, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/contextlib.py", line 137, in __enter__\n    return next(self.gen)\n           ^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "src/netCDF4/_netCDF4.pyx", line 2470, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2107, in netCDF4._netCDF4._ensure_nc_success\n'
#
# 2024-11-27 22:26:20,928 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-fc67bc40-5aa6-468b-9442-08c857ac51c5
# State:     executing
# Function:  execute_task
# args:      ((<function apply at 0x14d7562fd6c0>, <function open_dataset at 0x14d737824220>, ['/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L098_j000_ocean_1d_surface_tso.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [])], ['decode_times', False]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/dask/utils.py", line 78, in apply\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py", line 611, in open_dataset\n    backend_ds = backend.open_dataset(\n                 ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 649, in open_dataset\n    store = NetCDF4DataStore.open(\n            ^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 410, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 357, in __init__\n    self.format = self.ds.data_model\n                  ^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 419, in ds\n    return self._acquire()\n           ^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 413, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/contextlib.py", line 137, in __enter__\n    return next(self.gen)\n           ^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "src/netCDF4/_netCDF4.pyx", line 2470, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2107, in netCDF4._netCDF4._ensure_nc_success\n'
#
# 2024-11-27 22:26:20,930 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-96543b8e-2d80-4fb1-ba29-a35fa21f654b
# State:     executing
# Function:  execute_task
# args:      ((<function apply at 0x147fb4c456c0>, <function open_dataset at 0x147f96210220>, ['/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L018_j120_ocean_1d_surface_tso.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [])], ['decode_times', False]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/dask/utils.py", line 78, in apply\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py", line 611, in open_dataset\n    backend_ds = backend.open_dataset(\n                 ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 649, in open_dataset\n    store = NetCDF4DataStore.open(\n            ^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 410, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 357, in __init__\n    self.format = self.ds.data_model\n                  ^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 419, in ds\n    return self._acquire()\n           ^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 413, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/contextlib.py", line 137, in __enter__\n    return next(self.gen)\n           ^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "src/netCDF4/_netCDF4.pyx", line 2470, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2107, in netCDF4._netCDF4._ensure_nc_success\n'
#
# 2024-11-27 22:26:20,929 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-b971db54-3618-45dc-b0bc-8f1e38bfa13f
# State:     executing
# Function:  execute_task
# args:      ((<function apply at 0x1551179116c0>, <function open_dataset at 0x1550fcedff60>, ['/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L137_j120_ocean_1d_surface_tso.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [])], ['decode_times', False]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/dask/utils.py", line 78, in apply\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py", line 611, in open_dataset\n    backend_ds = backend.open_dataset(\n                 ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 649, in open_dataset\n    store = NetCDF4DataStore.open(\n            ^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 410, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 357, in __init__\n    self.format = self.ds.data_model\n                  ^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 419, in ds\n    return self._acquire()\n           ^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 413, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/contextlib.py", line 137, in __enter__\n    return next(self.gen)\n           ^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "src/netCDF4/_netCDF4.pyx", line 2470, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2107, in netCDF4._netCDF4._ensure_nc_success\n'
#
# 2024-11-27 22:26:20,931 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-627f0723-4d54-4c46-9148-d1629ee95ed0
# State:     executing
# Function:  execute_task
# args:      ((<function apply at 0x14849a6cd6c0>, <function open_dataset at 0x14847bc28360>, ['/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L019_j000_ocean_1d_surface_tso.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [])], ['decode_times', False]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# ...
# args:      ((<function apply at 0x147fb4c456c0>, <function open_dataset at 0x147f96210220>, ['/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L062_j000_ocean_1d_surface_tso.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [])], ['decode_times', False]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/dask/utils.py", line 78, in apply\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py", line 611, in open_dataset\n    backend_ds = backend.open_dataset(\n                 ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 649, in open_dataset\n    store = NetCDF4DataStore.open(\n            ^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 410, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 357, in __init__\n    self.format = self.ds.data_model\n                  ^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 419, in ds\n    return self._acquire()\n           ^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 413, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/contextlib.py", line 137, in __enter__\n    return next(self.gen)\n           ^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "src/netCDF4/_netCDF4.pyx", line 2470, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2107, in netCDF4._netCDF4._ensure_nc_success\n'
#
# 2024-11-27 22:26:21,119 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-a2d977cb-9890-4fdf-8133-85efd7c77f01
# State:     executing
# Function:  execute_task
# args:      ((<function apply at 0x14e3c10716c0>, <function open_dataset at 0x14e3a263c0e0>, ['/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L183_j120_ocean_1d_surface_tso.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [])], ['decode_times', False]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/dask/utils.py", line 78, in apply\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py", line 611, in open_dataset\n    backend_ds = backend.open_dataset(\n                 ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 649, in open_dataset\n    store = NetCDF4DataStore.open(\n            ^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 410, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 357, in __init__\n    self.format = self.ds.data_model\n                  ^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 419, in ds\n    return self._acquire()\n           ^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 413, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/contextlib.py", line 137, in __enter__\n    return next(self.gen)\n           ^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "src/netCDF4/_netCDF4.pyx", line 2470, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2107, in netCDF4._netCDF4._ensure_nc_success\n'
#
# 2024-11-27 22:26:21,120 - distributed.worker - ERROR - Compute Failed
# Key:       open_dataset-dca9373e-d997-4730-a4cf-212c294cc1d2
# State:     executing
# Function:  execute_task
# args:      ((<function apply at 0x14a4109dd6c0>, <function open_dataset at 0x14a3f1f98040>, ['/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L102_j120_ocean_1d_surface_tso.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [])], ['decode_times', False]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/dask/utils.py", line 78, in apply\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py", line 611, in open_dataset\n    backend_ds = backend.open_dataset(\n                 ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 649, in open_dataset\n    store = NetCDF4DataStore.open(\n            ^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 410, in open\n    return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 357, in __init__\n    self.format = self.ds.data_model\n                  ^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 419, in ds\n    return self._acquire()\n           ^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py", line 413, in _acquire\n    with self._manager.acquire_context(needs_lock) as root:\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/contextlib.py", line 137, in __enter__\n    return next(self.gen)\n           ^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context\n    file, cached = self._acquire_with_cache_info(needs_lock)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "src/netCDF4/_netCDF4.pyx", line 2470, in netCDF4._netCDF4.Dataset.__init__\n  File "src/netCDF4/_netCDF4.pyx", line 2107, in netCDF4._netCDF4._ensure_nc_success\n'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py:211, in _acquire_with_cache_info()
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File /home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/lru_cache.py:56, in __getitem__()
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L107_j120_ocean_1d_surface_tso.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'c915519d-67d0-4e8c-99fa-b50266127d84']
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 flistb=[[fnameCanESMDetrFitByLead(workdir, climyrs[0],climyrs[-1], ilead, yind) for yind in [0,60,120]] for ilead in range(0,215)]
# ----> 2 fb=xr.open_mfdataset(flistb,combine='nested',concat_dim=['leadtime','lat'],parallel=True,decode_times=False)
#       3 desstr=f'_ClimS{smoothmethod}{window}'
#       4 flistbS0=[[fnameCanESMDetrFitByLead(workdir, climyrs[0],climyrs[-1], ilead, yind,desstr) for yind in [0,60,120]] for ilead in range(0,215)]
#
# File /home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py:1145, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1140     datasets = [preprocess(ds) for ds in datasets]
#    1142 if parallel:
#    1143     # calling compute here will return the datasets/file_objs lists,
#    1144     # the underlying datasets will still be stored as dask arrays
# -> 1145     datasets, closers = dask.compute(datasets, closers)
#    1147 # Combine all datasets, closing them in case of a ValueError
#    1148 try:
#
# File /home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/dask/base.py:660, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     657     postcomputes.append(x.__dask_postcompute__())
#     659 with shorten_traceback():
# --> 660     results = schedule(dsk, keys, **kwargs)
#     662 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/api.py:611, in open_dataset()
#     599 decoders = _resolve_decoders_kwargs(
#     600     decode_cf,
#     601     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     607     decode_coords=decode_coords,
#     608 )
#     610 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 611 backend_ds = backend.open_dataset(
#     612     filename_or_obj,
#     613     drop_variables=drop_variables,
#     614     **decoders,
#     615     **kwargs,
#     616 )
#     617 ds = _dataset_from_backend_dataset(
#     618     backend_ds,
#     619     filename_or_obj,
#    (...)
#     629     **kwargs,
#     630 )
#     631 return ds
#
# File /home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:649, in open_dataset()
#     628 def open_dataset(  # type: ignore[override]  # allow LSP violation, not supporting **kwargs
#     629     self,
#     630     filename_or_obj: str | os.PathLike[Any] | BufferedIOBase | AbstractDataStore,
#    (...)
#     646     autoclose=False,
#     647 ) -> Dataset:
#     648     filename_or_obj = _normalize_path(filename_or_obj)
# --> 649     store = NetCDF4DataStore.open(
#     650         filename_or_obj,
#     651         mode=mode,
#     652         format=format,
#     653         group=group,
#     654         clobber=clobber,
#     655         diskless=diskless,
#     656         persist=persist,
#     657         lock=lock,
#     658         autoclose=autoclose,
#     659     )
#     661     store_entrypoint = StoreBackendEntrypoint()
#     662     with close_on_error(store):
#
# File /home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:410, in open()
#     404 kwargs = dict(
#     405     clobber=clobber, diskless=diskless, persist=persist, format=format
#     406 )
#     407 manager = CachingFileManager(
#     408     netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     409 )
# --> 410 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File /home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:357, in __init__()
#     355 self._group = group
#     356 self._mode = mode
# --> 357 self.format = self.ds.data_model
#     358 self._filename = self.ds.filepath()
#     359 self.is_remote = is_remote_uri(self._filename)
#
# File /home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:419, in ds()
#     417 @property
#     418 def ds(self):
# --> 419     return self._acquire()
#
# File /home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:413, in _acquire()
#     412 def _acquire(self, needs_lock=True):
# --> 413     with self._manager.acquire_context(needs_lock) as root:
#     414         ds = _nc4_require_group(root, self._group, self._mode)
#     415     return ds
#
# File /home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/contextlib.py:137, in __enter__()
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py:199, in acquire_context()
#     196 @contextlib.contextmanager
#     197 def acquire_context(self, needs_lock=True):
#     198     """Context manager for acquiring a file."""
# --> 199     file, cached = self._acquire_with_cache_info(needs_lock)
#     200     try:
#     201         yield file
#
# File /home/ords/crd/ccrn/reo000/miniconda3/envs/py12MHW/lib/python3.12/site-packages/xarray/backends/file_manager.py:217, in _acquire_with_cache_info()
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File src/netCDF4/_netCDF4.pyx:2470, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:2107, in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/space/hall5/sitestore/eccc/crd/ccrn/users/reo000/work/MHW_daily/byLeadDetr/fitDetrByLead_cwao_CanESM5.1p1bc-v20240611_hindcast_C1993_2023_L107_j120_ocean_1d_surface_tso.nc'

# %%
flistbS[0][0]

# %%
fb.leadtime

# %%
# trend only
fig,ax=plt.subplots(1,1,figsize=(12,7))
t=fb.leadtime.values # already in days in this file
ax.plot(t,fb.fit.isel(b=1,lat=iy,lon=ix),'k.',zorder=1)
m=ax.scatter(t,fbS0.fit.isel(b=1,lat=iy,lon=ix),c=fbS0.leadtime.values,s=3,cmap=plt.get_cmap('jet'),zorder=2)
ax.plot(t,fbS.fit.isel(b=1,lat=iy,lon=ix),'k-',zorder=3,alpha=.5)
fig.colorbar(m,label='lead time (days)')
ax.set_title('SST Trend')
ax.set_xlabel('Lead Time (days)')
ax.set_ylabel('SST Trend (K/month)')
ax.set_xlim(0,215)

# %%
plt.pcolormesh(fbS.fit.isel(b=1,leadtime=1)-fb.fit.isel(b=1,leadtime=1))
plt.colorbar()

# %%
# detrended threshold only
flistthresh=[[fnameCanESMAnomDetrQtile(workdir, climyrs[0],climyrs[-1], ilead, yind, qtile,False,False) for yind in [0,60,120]] for ilead in range(0,215)]
fthr=xr.open_mfdataset(flistthresh,combine='nested',concat_dim=['leadtime','lat'],parallel=True,decode_times=False)
flistthreshS=[[fnameCanESMAnomDetrQtile(workdir, climyrs[0],climyrs[-1], ilead, yind, qtile,True,True,method,halfwin,delt=5) for yind in [0,60,120]] for ilead in range(0,215)]
fthrS=xr.open_mfdataset(flistthreshS,combine='nested',concat_dim=['leadtime','lat'],parallel=True,decode_times=False)

# %%
fthr

# %%
fthrS

# %%
flistthreshS[0]

# %%
fnameCanESMAnomDetrQtile(workdir, climyrs[0],climyrs[-1], 5, 0, qtile,True,True,method,halfwin,delt=5)

# %%
fig,ax=plt.subplots(1,1,figsize=(12,7))
for mm in range(1,13):
    t=(dt.datetime(2024,mm,1)-dt.datetime(2023,12,31)).total_seconds()/(24*3600)+fthr.leadtime.values
    t=t%365
    m=ax.scatter(t,fthr.qt2.isel(month=mm-1,lat=iy,lon=ix),c=fthr.leadtime.values,s=3,cmap=plt.get_cmap('jet'),alpha=.3)
fig.colorbar(m,label='lead time (days)')
ax.set_title('SST Threshold for Detrended Anomalies: 3 month')
ax.set_xlabel('Day of Year')
ax.set_ylabel('SST (K)')
ax.set_xlim(0,366)

# %%
fig,ax=plt.subplots(1,1,figsize=(12,7))
for mm in range(1,13):
    t=(dt.datetime(2024,mm,1)-dt.datetime(2023,12,31)).total_seconds()/(24*3600)+fthr.leadtime.values
    t=t%365
    m=ax.scatter(t,fthrS.qt2.isel(month=mm-1,lat=iy,lon=ix),c=fthr.leadtime.values,s=3,cmap=plt.get_cmap('jet'),alpha=.3)
fig.colorbar(m,label='lead time (days)')
ax.set_title('Smoothed SST Threshold for Detrended Anomalies: 3 month')
ax.set_xlabel('Day of Year')
ax.set_ylabel('SST (K)')
ax.set_xlim(0,366)

# %%
fig,ax=plt.subplots(1,1,figsize=(12,7))
for mm in range(1,13):
    t=(dt.datetime(2024,mm,1)-dt.datetime(2023,12,31)).total_seconds()/(24*3600)+fthr.leadtime.values
    t=t%365
    m=ax.scatter(t,fthr.qt1.isel(month=mm-1,lat=iy,lon=ix),c=fthr.leadtime.values,s=3,cmap=plt.get_cmap('jet'),alpha=.3)
fig.colorbar(m,label='lead time (days)')
ax.set_title('SST Threshold for Detrended Anomalies: 1 month')
ax.set_xlabel('Day of Year')
ax.set_ylabel('SST (K)')
ax.set_xlim(0,366)

# %%
fig,ax=plt.subplots(1,1,figsize=(12,7))
for mm in range(1,13):
    t=(dt.datetime(2024,mm,1)-dt.datetime(2023,12,31)).total_seconds()/(24*3600)+fthr.leadtime.values
    t=t%365
    m=ax.scatter(t,fthrS.qt1.isel(month=mm-1,lat=iy,lon=ix),c=fthr.leadtime.values,s=3,cmap=plt.get_cmap('jet'),alpha=.3)
fig.colorbar(m,label='lead time (days)')
ax.set_title('Smoothed SST Threshold for Detrended Anomalies: 1 month')
ax.set_xlabel('Day of Year')
ax.set_ylabel('SST (K)')
ax.set_xlim(0,366)

# %%
# ball: clim + qt + max adjustment due to trend (overestimate)
fig,ax=plt.subplots(1,1,figsize=(12,7))
for mm in range(1,13):
    t=(dt.datetime(2024,mm,1)-dt.datetime(2023,12,31)).total_seconds()/(24*3600)+fthr.leadtime.values
    t=t%365
    m=ax.scatter(t,fclim.tso.isel(month=mm-1,lat=iy,lon=ix).values+fthr.qt2.isel(month=mm-1,lat=iy,lon=ix)-\
                 fb.fit.isel(b=1,lat=iy,lon=ix).values*(30*12),c=fthr.leadtime.values,s=3,cmap=plt.get_cmap('jet'),alpha=.3)
fig.colorbar(m,label='lead time (days)')
ax.set_title('Indiv SST Threshold with max trend subtraction (~30 yrs)= Climatology + Anomaly Threshold+Trend*30 yrs')
ax.set_xlabel('Day of Year')
ax.set_ylabel('SST (K)')
ax.set_xlim(0,366)

# %%
# ball: clim + qt + max adjustment due to trend (overestimate)
fig,ax=plt.subplots(1,1,figsize=(12,7))
for mm in range(1,13):
    t=(dt.datetime(2024,mm,1)-dt.datetime(2023,12,31)).total_seconds()/(24*3600)+fthr.leadtime.values
    t=t%365
    m=ax.scatter(t,fclimS.tso.isel(month=mm-1,lat=iy,lon=ix).values+fthrS.qt2.isel(month=mm-1,lat=iy,lon=ix)-\
                 fbS.fit.isel(b=1,lat=iy,lon=ix).values*(30*12),c=fthr.leadtime.values,s=3,cmap=plt.get_cmap('jet'),alpha=.3)
fig.colorbar(m,label='lead time (days)')
ax.set_title('Smoothed SST Threshold with max trend subtraction (~30 yrs)= Climatology + Anomaly Threshold+Trend*30 yrs')
ax.set_xlabel('Day of Year')
ax.set_ylabel('SST (K)')
ax.set_xlim(0,366)

# %%
# ball: clim + qt + max adjustment due to trend (overestimate)
fig,ax=plt.subplots(1,1,figsize=(12,7))
for mm in range(1,13):
    t=(dt.datetime(2024,mm,1)-dt.datetime(2023,12,31)).total_seconds()/(24*3600)+fthr.leadtime.values
    t=t%365
    m=ax.scatter(t,fclimS.tso.isel(month=mm-1,lat=iy,lon=ix).values+fthrS.qt2.isel(month=mm-1,lat=iy,lon=ix)-\
                 fbS.fit.isel(b=1,lat=iy,lon=ix).values*(30*12),c=fthr.leadtime.values,s=3,cmap=plt.get_cmap('jet'),alpha=.3)
fig.colorbar(m,label='lead time (days)')
ax.set_title('Smoothed SST Threshold with max trend subtraction (~30 yrs)= Climatology + Anomaly Threshold+Trend*30 yrs')
ax.set_xlabel('Day of Year')
ax.set_ylabel('SST (K)')
ax.set_xlim(180,240)
ax.set_ylim(300,302)

# %%
fb.close(); fclim.close(); 
fthr.close()
fbS.close(); fclimS.close(); 
fthrS.close()

# %%
client.close()

# %%
cluster.close()
